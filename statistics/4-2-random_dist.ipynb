# %% [markdown]
# # [Think Stats Chapter 4 Exercise 2](http://greenteapress.com/thinkstats2/html/thinkstats2005.html#toc41) (a random distribution)

# %% [markdown]
# **Exercise 2**   The numbers generated by random.random are supposed to be uniform between 0 and 1; that is, every value in the range should have the same probability.
# Generate 1000 numbers from random.random and plot their PMF and CDF. Is the distribution uniform?

# %%
import random, thinkstats2

nums = []
for i in range(1000):
    nums.append(random.random())
nums_pmf = thinkstats2.Pmf(nums,label='random numbers')

# %%
import thinkplot
# %matplotlib inline

thinkplot.Pmf(nums_pmf)

# %% [markdown]
# The plot for the PDF shows that each value has a nearly equal probability. Which leads me to believe that random numbers were generated. However, we can also check the CDF of the list to confirm.

# %%
nums_cdf = thinkstats2.Cdf(nums, label='random numbers')
thinkplot.Cdf(nums_cdf)
# Out:
# {'xscale': 'linear', 'yscale': 'linear'}

# %% [markdown]
# The line for the CDF is linear, meaning that the distribution is uniform. So yes, random.random does generate fairly random numbers.
